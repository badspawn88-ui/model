# %% [markdown]
# # SadTalker On Kaggle

# %% [markdown]
# **!!! Use GPU P100 as Accelerator !!!**
# > SadTalker Dosen't Work On Multi GPU so T4 So It Will Give Less It/s
#
# 1. Click on the Data tab. On the right side of the page.
# 2. click on the Data button.
# 3. Click on the + Add Data button.
# 4. Upload a .png Image & .wav Audio File.

# %% [markdown]
# **Code Will Install SadTalker To Kaggle Instance**

# %%
# !git clone https://github.com/OpenTalker/SadTalker.git
# %cd SadTalker
# !pip install -r requirements.txt

# %% [markdown]
# **Code will download models and install TTS**

# %%
# !bash scripts/download_models.sh
# !pip install TTS

# %% [markdown]
# **Now lets add your audio file and image file**
# 1. Click on dataset You uploaded click on audio file click on copy button to copy path of audio file.
# 2. Paste The Path beside --driven_audio in below code.
# 3. Click on dataset You uploaded click on Image file click on copy button to copy path of image file.
# 4. Paste The Path beside --source_image in below code.

# %%
# !python inference.py --driven_audio /Your/File/Directory/audio/audio.wav --source_image /Your/File/Directory/image/image.png --preprocess full --enhancer gfpgan --still

# %% [markdown]
# **Your File Will Be Saved In Output:- /kaggle/working/SadTalker/Results**
# 1.  If u are Getting Same Error
#  > Could not load more files: You must specify exactly one databundle source
# ***Just Click On Refresh Option Beside Directory It Will Show You Files***
